# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = {"Name":["abc","pqr","xyz"], "Age":[22,35,58],"Gender":["Male","Female","Male"]}
df
# Out:
# {'Name': ['abc', 'pqr', 'xyz'],
#  'Age': [22, 35, 58],
#  'Gender': ['Male', 'Female', 'Male']}

# %%
dff = pd.DataFrame(df, index=["A","B","C"])
dff
# Out:
#   Name  Age  Gender
# A  abc   22    Male
# B  pqr   35  Female
# C  xyz   58    Male

# %%
titanic_data = pd.read_csv("titanic.csv")
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic_data["Age"].head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64

# %%
titanic_data.shape
# Out:
# (891, 12)

# %%
titanic_data[["Age", "Sex"]].head()
# Out:
#     Age     Sex
# 0  22.0    male
# 1  38.0  female
# 2  26.0  female
# 3  35.0  female
# 4  35.0    male

# %%
titanic_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_data[titanic_data["Survived"]==1].head()
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
titanic_data.loc[titanic_data["Age"]>35,"Name"].head()
# Out:
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...
# 6                               McCarthy, Mr. Timothy J
# 11                             Bonnell, Miss. Elizabeth
# 13                          Andersson, Mr. Anders Johan
# 15                     Hewlett, Mrs. (Mary D Kingcome)
# Name: Name, dtype: object

# %%
titanic_data.iloc[2:10,0:3]
# Out:
#    PassengerId  Survived  Pclass
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2

# %%
titanic_data.agg({
    "Age":["min", "max", "median","skew"],
    "Fare":["min","max","median","mean"]
})
# Out:
#               Age        Fare
# min      0.420000    0.000000
# max     80.000000  512.329200
# median  28.000000   14.454200
# skew     0.389108         NaN
# mean          NaN   32.204208

# %%
titanic_data[["Sex","Age"]].groupby("Sex").agg(["mean","median","count"])
# Out:
#               Age
#              mean median count
# Sex
# female  27.915709   27.0   261
# male    30.726645   29.0   453

# %%
titanic_data.groupby(["Sex","Pclass"])["Age"].mean()
# Out:
# Sex     Pclass
# female  1         34.611765
#         2         28.722973
#         3         21.750000
# male    1         41.281386
#         2         30.740707
#         3         26.507589
# Name: Age, dtype: float64

# %%
titanic_data["Pclass"].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
titanic_data.groupby("Pclass")["Pclass"].count()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Pclass, dtype: int64

# %%
titanic_data.sort_values(by="Age", ascending=False).head()
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 630  male  80.0      0      0     27042  30.0000   A23        S
# 851  male  74.0      0      0    347060   7.7750   NaN        S
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C
# 116  male  70.5      0      0    370369   7.7500   NaN        Q

# %%
titanic_data.sort_values(by=["Age","Pclass"], ascending=False).head()
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 96            97         0       1             Goldschmidt, Mr. George B
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 116          117         0       3                  Connors, Mr. Patrick
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 630  male  80.0      0      0     27042  30.0000   A23        S
# 851  male  74.0      0      0    347060   7.7750   NaN        S
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C
# 116  male  70.5      0      0    370369   7.7500   NaN        Q

# %%
titanic_data["Pclass"].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
titanic_data["Pclass"].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
titanic_data["Name"].str.lower().head()
# Out:
# 0                              braund, mr. owen harris
# 1    cumings, mrs. john bradley (florence briggs th...
# 2                               heikkinen, miss. laina
# 3         futrelle, mrs. jacques heath (lily may peel)
# 4                             allen, mr. william henry
# Name: Name, dtype: object

# %%
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_data["Name"].str.len().head()
# Out:
# 0    23
# 1    51
# 2    22
# 3    44
# 4    24
# Name: Name, dtype: int64

# %%
titanic_data["Name"].str.len().idxmax()
# Out:
# 307

# %%
titanic_data.loc[titanic_data["Name"].str.len().idxmax(),"Name"]
# Out:
# 'Penasco y Castellana, Mrs. Victor de Satode (Maria Josefa Perez de Soto y Vallejo)'

# %%
titanic_data["Sex"].replace({"male":"m", "female":"F"}).head()
# Out:
# 0    m
# 1    F
# 2    F
# 3    F
# 4    m
# Name: Sex, dtype: object

# %%
import numpy as np
df = pd.DataFrame(np.random.randn(10,3),columns=list("abc"))
df
# Out:
#           a         b         c
# 0  0.770055 -0.828775 -1.375583
# 1 -1.097022  1.315812 -1.360120
# 2  0.321568  1.023594  1.030864
# 3 -0.191687 -1.216025 -0.197459
# 4 -0.059777 -0.685787  1.191094
# 5 -1.734795  1.142124  0.926686
# 6  0.804576  0.807616  0.386134
# 7 -1.709796 -0.867502  0.983999
# 8 -0.267765 -0.537870  0.469102
# 9 -0.063765  0.060043  0.391988

# %%
df.loc[:,["a","c"]].head()
# Out:
#           a         c
# 0  0.770055 -1.375583
# 1 -1.097022 -1.360120
# 2  0.321568  1.030864
# 3 -0.191687 -0.197459
# 4 -0.059777  1.191094

# %%
import numpy as np
named = list('abcdef')
n = 30
column = named + [str(i) for i in range(len(named), n)]
df = pd.DataFrame(np.random.randn(n,n), columns=column)
df.head()
# Out:
#           a         b         c         d         e         f         6  \
# 0  0.067303  1.216656  0.649519 -1.256762 -0.722536  0.593904  0.544946
# 1  0.541962  2.555107  0.761993  0.596190  0.043210  1.944228  1.853731
# 2 -1.291597  1.208235 -0.126026 -0.036433  0.301504  0.134146  0.818858
# 3 -0.655432 -0.124920 -1.472042  0.050051 -0.119257 -0.364331 -0.220197
# 4  0.322229 -0.050570 -0.614636  1.957827  0.960214 -1.849723 -0.554043
#
#           7         8         9  ...        20        21        22        23  \
# 0 -0.470974 -0.390634 -0.204856  ... -0.416073  0.865938 -0.607856 -0.968124
# 1  0.355631 -0.091275 -2.036352  ... -0.138462 -0.956950  1.744699  0.383872
# 2 -0.909752  1.362318 -1.341538  ...  0.216353 -0.293729 -0.202929 -0.378916
# 3  2.264629 -0.732952 -0.634631  ...  0.949962  1.711380 -0.031477  0.037275
# 4  1.051194 -0.416766 -0.099820  ...  0.480027 -0.780769  0.118400  0.718439
#
#          24        25        26        27        28        29
# ...

# %%
import numpy as np
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16768\1662815981.py in <module>
#       1 import numpy as np
# ----> 2 import pandas as pd
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\__init__.py in <module>
#      20
#      21 # numpy compat
# ---> 22 from pandas.compat import is_numpy_dev as _is_numpy_dev
#      23
#      24 try:
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\compat\__init__.py in <module>
#      13
#      14 from pandas._typing import F
# ---> 15 from pandas.compat.numpy import (
#      16     is_numpy_dev,
#      17     np_version_under1p19,
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\compat\numpy\__init__.py in <module>
#       2 import numpy as np
#       3
# ----> 4 from pandas.util.version import Version
#       5
#       6 # numpy versioning
#
# ...
